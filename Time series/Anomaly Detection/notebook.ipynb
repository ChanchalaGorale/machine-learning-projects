# %% [markdown]
# # Anomaly Detection

# %%
import pandas as pd
import tensorflow as tf
from keras.layers import Input, Dense
from keras.models import Model
from sklearn.metrics import precision_recall_fscore_support
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/ambient_temperature_system_failure.csv')

data_values = data.drop('timestamp',
                        axis=1).values

data_values = data_values.astype('float32')

data_converted = pd.DataFrame(data_values,
                              columns=data.columns[1:])

data_converted.insert(0, 'timestamp',
                      data['timestamp'])

# %%
data_converted = data_converted.dropna()

# %%
data_tensor = tf.convert_to_tensor(data_converted.drop(
    'timestamp', axis=1).values, dtype=tf.float32)

input_dim = data_converted.shape[1] - 1
encoding_dim = 10

input_layer = Input(shape=(input_dim,))
encoder = Dense(encoding_dim, activation='relu')(input_layer)
decoder = Dense(input_dim, activation='relu')(encoder)
autoencoder = Model(inputs=input_layer, outputs=decoder)

autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.fit(data_tensor, data_tensor, epochs=50,
                batch_size=32, shuffle=True)

reconstructions = autoencoder.predict(data_tensor)
mse = tf.reduce_mean(tf.square(data_tensor - reconstructions),
                     axis=1)
anomaly_scores = pd.Series(mse.numpy(), name='anomaly_scores')
anomaly_scores.index = data_converted.index
# Out:
# Epoch 1/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2557.4524
# Epoch 2/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 306.9787
# Epoch 3/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.6777
# Epoch 4/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0019
# Epoch 5/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0016
# Epoch 6/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0015
# Epoch 7/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0015
# Epoch 8/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0015
# Epoch 9/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0015
# Epoch 10/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0015
# Epoch 11/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0015
# Epoch 12/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0015
# Epoch 13/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0015
# Epoch 14/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0015
# Epoch 15/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0015
# Epoch 16/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0015
# Epoch 17/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0015
# Epoch 18/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0015
# Epoch 19/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0015
# Epoch 20/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0015
# Epoch 21/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0015
# Epoch 22/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0015
# Epoch 23/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0015
# Epoch 24/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0015
# Epoch 25/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0015
# Epoch 26/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0015
# Epoch 27/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0015
# Epoch 28/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0015
# Epoch 29/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0015
# Epoch 30/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0015
# Epoch 31/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0014
# Epoch 32/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0015
# Epoch 33/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0015
# Epoch 34/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0014
# Epoch 35/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0014
# Epoch 36/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0014
# Epoch 37/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0013
# Epoch 38/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0013
# Epoch 39/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0014
# Epoch 40/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0013
# Epoch 41/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0013
# Epoch 42/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0013
# Epoch 43/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0012
# Epoch 44/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0012
# Epoch 45/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0012
# Epoch 46/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0012
# Epoch 47/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0011
# Epoch 48/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0011
# Epoch 49/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.9706e-04
# Epoch 50/50
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.5703e-04
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
threshold = anomaly_scores.quantile(0.99)
anomalous = anomaly_scores > threshold
binary_labels = anomalous.astype(int)
precision, recall,\
    f1_score, _ = precision_recall_fscore_support(
        binary_labels, anomalous, average='binary')

# %%
test = data_converted['value'].values
predictions = anomaly_scores.values

print("Precision: ", precision)
print("Recall: ", recall)
print("F1 Score: ", f1_score)
# Out:
# Precision:  1.0
# Recall:  1.0
# F1 Score:  1.0

# %%
plt.figure(figsize=(16, 8))

plt.plot(data_converted['timestamp'], data_converted['value'])
plt.plot(data_converted['timestamp'][anomalous], data_converted['value'][anomalous], 'ro')

plt.title('Anomaly Detection')
plt.xlabel('Time')
plt.ylabel('Value')

plt.show()
